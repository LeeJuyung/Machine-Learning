# %%
import pandas as pd
import numpy as np

data = pd.read_csv('data/heights.csv')
data
# Out:
#          mother      father         son
# 0    177.097885  171.552438  192.283639
# 1    180.712858  174.827844  192.221714
# 2    178.198234  185.601788  191.961618
# 3    175.632072  172.551166  191.927836
# 4    167.747365  180.752648  190.754076
# ..          ...         ...         ...
# 990  151.639638  169.588205  159.361988
# 991  148.616215  163.707877  158.810274
# 992  150.343611  177.552299  158.663132
# 993  156.918027  162.419259  158.402096
# 994  147.753030  176.489411  158.001792
#
# [995 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# mother    0
# father    0
# son       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

X= data["mother"]
y = data["son"]

plt.plot(X,y,'.')
plt.xlabel('Mother')
plt.ylabel('Son')
# Out:
# Text(0, 0.5, 'Son')

# %%
import matplotlib.pyplot as plt

X= data["father"]
y = data["son"]

plt.plot(X,y,'.')
plt.xlabel('Father')
plt.ylabel('Son')
# Out:
# Text(0, 0.5, 'Son')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.5, random_state=0)

# %%
df=data
X = df.drop(['son'], axis=1)
y=df[['son']]

X
# Out:
#          mother      father
# 0    177.097885  171.552438
# 1    180.712858  174.827844
# 2    178.198234  185.601788
# 3    175.632072  172.551166
# 4    167.747365  180.752648
# ..          ...         ...
# 990  151.639638  169.588205
# 991  148.616215  163.707877
# 992  150.343611  177.552299
# 993  156.918027  162.419259
# 994  147.753030  176.489411
#
# [995 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
my_apt = [[150,180]]
mlr.predict(my_apt)
# Out:
# C:\Users\jylpi\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[170.40021001]])

# %%
#회귀계수 (기울기와 절편)
[lr.coef_, lr.intercept_]
# Out:
# [array([[0.5396177, 0.2933562]]), array([36.6534394])]

# %%
#예측값과 실제값 비교 (지도학습이고 실제값이 있으니까 비교해보는거)
y_pred= mlr.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred, alpha = 0.4)
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# %%
print("MAE : %.2f" %mae)
print("MSE : %.2f" %mse)
print("RMSE : %.2f" %rmse)
print("R2 : %.2f" %r2)
# Out:
# MAE : 3.67
# MSE : 21.23
# RMSE : 4.61
# R2 : 0.50
